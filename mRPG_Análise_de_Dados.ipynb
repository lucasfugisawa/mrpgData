# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasfugisawa/mrpgData/blob/main/mRPG_An%C3%A1lise_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

uri = "https://raw.githubusercontent.com/lucasfugisawa/mrpgData/main/campaignsPerUser.csv"

campaignsPerUser = pd.read_csv(uri)

campaignsPerUser.describe()
# Out:
#            campaigns  lfp_campaigns
# count  102016.000000  102016.000000
# mean        2.097377       0.149643
# std         5.353805       1.216397
# min         1.000000       0.000000
# 25%         1.000000       0.000000
# 50%         1.000000       0.000000
# 75%         2.000000       0.000000
# max       314.000000     127.000000
